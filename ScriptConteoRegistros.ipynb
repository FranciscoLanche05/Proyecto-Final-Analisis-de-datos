# %%
# ════════════════════════════════════════════════════════
#  INSTALACIÓN — copia y pega según lo que uses
# ════════════════════════════════════════════════════════


# ── BASE (siempre instala esto) ──────────────────────────
pip install pandas openpyxl xlrd


# ── FORMATOS DE ARCHIVO (solo los que necesites) ─────────
pip install pyarrow          # .parquet y .feather
pip install lxml             # .xml
pip install orc              # .orc (alternativa: pyarrow ya lo soporta)
pip install fastparquet      # .parquet alternativo (opcional)


# ── SQL (solo los que uses) ──────────────────────────────
pip install pyodbc           # SQL Server
pip install mysql-connector-python   # MySQL / MariaDB
pip install psycopg2-binary  # PostgreSQL
pip install oracledb         # Oracle XE (reemplaza a cx_Oracle)


# ── NoSQL ────────────────────────────────────────────────
pip install pymongo          # MongoDB


# ════════════════════════════════════════════════════════
#  TODO EN UNA LÍNEA (instalación completa)
# ════════════════════════════════════════════════════════
pip install pandas openpyxl xlrd pyarrow lxml pyodbc mysql-connector-python psycopg2-binary oracledb pymongo
# Out:
#   Cell In[4], line 7
#     pip install pandas openpyxl xlrd
#         ^
# SyntaxError: invalid syntax
